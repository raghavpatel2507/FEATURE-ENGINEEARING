# %%
import seaborn as sns

# %%
lst_marks=[56,45,78,98,36,54,68,76,49,87,82,81,69,62,60,1100,1200]

# %%
sns.boxplot(lst_marks)
# Out:
# <AxesSubplot: >

# %%
lst_marks=[56,45,78,98,36,54,68,76,49,87,82,81,69,62,60]

# %%
sns.boxplot(lst_marks)
# Out:
# <AxesSubplot: >
