# %% [markdown]
# ## Data Interpolation
# Data interpolation is the process of estimating unknown values within a dataset based on the known values. In Python, there are various libraries available that can be used for data interpolation, such as NumPy, SciPy, and Pandas. Here is an example of how to perform data interpolation using the NumPy library:

# %% [markdown]
# ## 1. Linear Interpolation

# %%
import numpy as np
x=np.array([1,2,3,4,5])
y=np.array([2,4,6,8,10])

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
## interpolate the data using linear interpolation
x_new=np.linspace(1,5,10) ##create new x values
y_interp=np.interp(x_new,x,y) ## interpolate y values
print(y_interp)
# Out:
# [ 2.          2.88888889  3.77777778  4.66666667  5.55555556  6.44444444
#   7.33333333  8.22222222  9.11111111 10.        ]

# %%
plt.scatter(x_new,y_interp)

# %%
from scipy.interpolate import interp1d

# %%
f=interp1d(x,y,kind='linear')

# %%
x_new=np.linspace(1,5,10)
y_interp=f(x_new)

# %%
print(y_interp)
# Out:
# [ 2.          2.88888889  3.77777778  4.66666667  5.55555556  6.44444444
#   7.33333333  8.22222222  9.11111111 10.        ]

# %%
plt.scatter(x_new,y_interp)

# %% [markdown]
# ## Cubic Interpolation With Scipy

# %%
import numpy as np
x=np.array([1,2,3,4,5])
y=np.array([1,8,27,64,125])

# %%
from scipy.interpolate import interp1d

# %%
f=interp1d(x,y,kind='cubic')

# %%
x_new=np.linspace(1,5,10)
y_interp=f(x_new)

# %%
print(y_interp)
# Out:
# [  1.           3.01371742   6.739369    12.7037037   21.43347051
#   33.45541838  49.2962963   69.48285322  94.54183813 125.        ]

# %%
plt.scatter(x_new,y_interp)

# %% [markdown]
# ## Polynomial Interpolation

# %%
import numpy as np

# create some sample data
x = np.array([1, 2, 3, 4, 5])
y = np.array([1, 4, 9, 16, 25])

# %%
# interpolate the data using polynomial interpolation
p = np.polyfit(x, y, 4) # fit a 2nd degree polynomial to the data

# %%
x_new = np.linspace(1, 5, 10) # create new x values
y_interp = np.polyval(p, x_new) # interpolate y values

# %%
print(y_interp)
# Out:
# [ 1.          2.08641975  3.56790123  5.44444444  7.71604938 10.38271605
#  13.44444444 16.90123457 20.75308642 25.        ]

# %%
plt.scatter(x_new,y_interp)

# %% [markdown]
# # practise

# %%
# linear
a=[1,2,3,4,5,6,7,8]
b=[2,4,6,8,10,12,14,16]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(a,b)

# %%
import numpy as np

# %%
from scipy.interpolate import interp1d

# %%
f=interp1d(a,b,kind='linear')

# %%
a_new=np.linspace(1,8,20)
y_interp=f(a_new)

# %%
print(y_interp)
# Out:
# [ 2.          2.73684211  3.47368421  4.21052632  4.94736842  5.68421053
#   6.42105263  7.15789474  7.89473684  8.63157895  9.36842105 10.10526316
#  10.84210526 11.57894737 12.31578947 13.05263158 13.78947368 14.52631579
#  15.26315789 16.        ]

# %%
plt.scatter(a_new,y_interp)

# %%
# cibic
a=[1,2,3,4,5]
b=[1,8,27,64,125]

# %%
f=interp1d(a,b,kind='cubic')

# %%
a_new=np.linspace(1,5,20)
y_interp=f(a_new)

# %%
print(y_interp)
# Out:
# [  1.           1.77387374   2.8696603    4.34334451   6.25091121
#    8.64834524  11.59163143  15.13675463  19.33969966  24.25645138
#   29.94299461  36.45531419  43.84939496  52.18122175  61.50677941
#   71.88205278  83.36302668  96.00568596 109.86601545 125.        ]

# %%
plt.scatter(a_new,y_interp)
